# %%
#importing libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#loading data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data_Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# c:\Users\Utilisateur\anaconda3\envs\python_again_vs_code\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Utilisateur\.cache\huggingface\hub\datasets--lukebarousse--data_jobs. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
#I had to use this method rather to import the data
import pandas as pd

df = pd.read_csv("hf://datasets/lukebarousse/data_jobs/data_jobs.csv")

# %%
#importing libraries
import matplotlib.pyplot as plt

#Data_Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

#everything is alright now and running fine

# %%
df.iloc[0:10]
df.loc[0:10]
# Out:
#          job_title_short  ...                                    job_type_skills
# 0   Senior Data Engineer  ...                                                NaN
# 1           Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2          Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3          Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4          Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# 5          Data Engineer  ...  {'cloud': ['gcp'], 'programming': ['python', '...
# 6   Senior Data Engineer  ...  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 7          Data Engineer  ...  {'cloud': ['gcp', 'azure', 'aws', 'bigquery', ...
# 8       Business Analyst  ...  {'analyst_tools': ['excel', 'powerpoint', 'pow...
# 9         Data Scientist  ...  {'analyst_tools': ['excel'], 'cloud': ['azure'...
# 10         Data Engineer  ...  {'cloud': ['databricks', 'azure'], 'libraries'...
#
# ...

# %%
#code to drop null (NaN) values in the salary rate column

#learned a lot with this one
# syntax of loc is  df.loc[row_selector, col_selector]
# : → all rows.
# 'salary_rate':'salary_hour_avg' → label slice over columns using loc, meaning all the columns from
# salary_rate to salary_hour_avg are selected in the order of the dataset
# Then for the salary_rate column, the NaN values are dropped

df.loc[:, 'salary_rate':'salary_hour_avg'].dropna(subset='salary_rate')

#rewriting the code to see if I truly understand and remember
#nailed it
df.loc[:,'salary_rate':'salary_hour_avg'].dropna(subset ='salary_rate')

# I asked C how to rewrite the code to drop NaN from several columns at once and he gave me this
# cols = ['salary_rate', 'salary_year_avg', 'salary_hour_avg']
# df_subset = (
#    df.loc[:, 'salary_rate':'salary_hour_avg']   # select the block
#     .dropna(subset=cols)                       # drop if ANY of these is NaN
# )
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 28            year         109500.0              NaN
# 43            hour              NaN             97.5
# 51            hour              NaN             72.5
# 77            year         140000.0              NaN
# 92            year         120000.0              NaN
# ...            ...              ...              ...
# 785624        year         139216.0              NaN
# 785641        year         150000.0              NaN
# 785648        year         221875.0              NaN
# 785682        year         157500.0              NaN
# 785692        year         157500.0              NaN
#
# [33067 rows x 3 columns]
